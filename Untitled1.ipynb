# %% [markdown]
# <a href="https://colab.research.google.com/github/sampathsahit/bussiness_dashboard-and-fraud_dectection/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/kaggle/data.csv", encoding="ISO-8859-1")

df = df.dropna(subset=["CustomerID"])

df = df[(df["Quantity"] > 0) & (df["UnitPrice"] > 0)]

df["Revenue"] = df["Quantity"] * df["UnitPrice"]

df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"])

df["Month"] = df["InvoiceDate"].dt.to_period("M")

# %%
print("Total Revenue =", round(df["Revenue"].sum(),2))
# Out:
# Total Revenue = 8911407.9

# %%
print("Total Orders =", df["InvoiceNo"].nunique())
# Out:
# Total Orders = 18532

# %%
print("Total Customers =", df["CustomerID"].nunique())
# Out:
# Total Customers = 4338

# %%
avg = df["Revenue"].sum()/df["InvoiceNo"].nunique()
print("Average Order Value =", round(avg,2))
# Out:
# Average Order Value = 480.87

# %%
monthly = df.groupby("Month")["Revenue"].sum()

plt.figure(figsize=(10,5))
monthly.plot(marker='o')
plt.title("Monthly Revenue")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.grid(True)
plt.show()

# %%
monthly = df.groupby("Month")["Revenue"].sum()

plt.figure(figsize=(10,5))
monthly.plot(marker='o')
plt.title("Monthly Revenue")
plt.xlabel("Month")
plt.ylabel("Revenue")
plt.grid(True)
plt.show()

# %%
top_products = df.groupby("Description")["Revenue"].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,5))
top_products.plot(kind="bar")
plt.title("Top 10 Products")
plt.ylabel("Revenue")
plt.xticks(rotation=90)
plt.show()

# %%
top_country = df.groupby("Country")["Revenue"].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,5))
top_country.plot(kind="bar")
plt.title("Top 10 Countries")
plt.ylabel("Revenue")
plt.xticks(rotation=45)
plt.show()

# %%
top_customer = df.groupby("CustomerID")["Revenue"].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,5))
top_customer.plot(kind="bar")
plt.title("Top 10 Customers")
plt.ylabel("Revenue")
plt.xticks(rotation=45)
plt.show()

# %%
print("Business Recommendations")
print("1. Focus marketing on the top revenue-generating countries.")
print("2. Maintain higher stock for best-selling products.")
print("3. Reward loyal customers with discounts.")
print("4. Analyze low-selling products and improve promotions.")
# Out:
# Business Recommendations
# 1. Focus marketing on the top revenue-generating countries.
# 2. Maintain higher stock for best-selling products.
# 3. Reward loyal customers with discounts.
# 4. Analyze low-selling products and improve promotions.
