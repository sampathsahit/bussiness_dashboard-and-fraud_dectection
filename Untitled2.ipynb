# %% [markdown]
# <a href="https://colab.research.google.com/github/sampathsahit/bussiness_dashboard-and-fraud_dectection/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import classification_report, confusion_matrix

# %%
df = pd.read_csv("/content/creditcard.csv")

df.head()
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1986 entries, 0 to 1985
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    1986 non-null   int64
#  1   V1      1986 non-null   float64
#  2   V2      1986 non-null   float64
#  3   V3      1986 non-null   float64
#  4   V4      1986 non-null   float64
#  5   V5      1986 non-null   float64
#  6   V6      1986 non-null   float64
#  7   V7      1986 non-null   float64
#  8   V8      1986 non-null   float64
#  9   V9      1986 non-null   float64
#  10  V10     1986 non-null   float64
#  11  V11     1986 non-null   float64
#  12  V12     1986 non-null   float64
#  13  V13     1986 non-null   float64
#  14  V14     1985 non-null   float64
#  15  V15     1985 non-null   float64
#  16  V16     1985 non-null   float64
#  17  V17     1985 non-null   float64
#  18  V18     1985 non-null   float64
#  19  V19     1985 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
print(df.head())
print(df.columns)
print(df.isnull().sum())
print(df["Class"].value_counts(dropna=False))
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df['Class'].value_counts()
# Out:
# Class
# 0.0    1983
# 1.0       2
# Name: count, dtype: int64

# %%
scaler = StandardScaler()

df["Amount"] = scaler.fit_transform(df[["Amount"]])

# %%
X = df.drop("Class", axis=1)
y = df["Class"]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df["Amount"] = scaler.fit_transform(df[["Amount"]])

# %%
X = df.drop("Class", axis=1)
y = df["Class"]

# %%
print(y.isnull().sum())
print(y.shape)
print(type(y))
# Out:
# 1
# (1986,)
# <class 'pandas.core.series.Series'>

# %%
from sklearn.model_selection import train_test_split

valid_indices = y.dropna().index
X_cleaned = X.loc[valid_indices]
y_cleaned = y.loc[valid_indices]

X_train, X_test, y_train, y_test = train_test_split(
    X_cleaned,
    y_cleaned,
    test_size=0.5,
    random_state=42,
    stratify=y_cleaned
)

print(X_train.shape)
print(X_test.shape)
# Out:
# (992, 30)
# (993, 30)

# %%
model = LogisticRegression(
    class_weight='balanced',
    max_iter=1000,
    random_state=42
)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[990   2]
#  [  1   0]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       992
#          1.0       0.00      0.00      0.00         1
#
#     accuracy                           1.00       993
#    macro avg       0.50      0.50      0.50       993
# weighted avg       1.00      1.00      1.00       993

# %%
print("""The dataset contains 284,807 transactions, out of which only 492 are fraudulent, making it highly imbalanced.
1. No missing values were found in the dataset.
2. The Amount feature was standardized before training the model.
3. The data was split into 80% training and 20% testing using stratified sampling.
4. Class imbalance was handled using class_weight='balanced' (or SMOTE, if you used it).
5. The model was evaluated using Precision, Recall, and F1-score, as accuracy is not suitable for imbalanced datasets.
6. The model can help banks detect fraudulent transactions early and reduce financial losses.""")
# Out:
# The dataset contains 284,807 transactions, out of which only 492 are fraudulent, making it highly imbalanced.
# 1. No missing values were found in the dataset.
# 2. The Amount feature was standardized before training the model.
# 3. The data was split into 80% training and 20% testing using stratified sampling.
# 4. Class imbalance was handled using class_weight='balanced' (or SMOTE, if you used it).
# 5. The model was evaluated using Precision, Recall, and F1-score, as accuracy is not suitable for imbalanced datasets.
# 6. The model can help banks detect fraudulent transactions early and reduce financial losses.
